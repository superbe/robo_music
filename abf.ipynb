# %%
# !pip install --upgrade pyabf

# %%
import pyabf
import matplotlib.pyplot as plt
import soundfile as sf
import IPython.display
import IPython.display as ipd
import pandas as pd

# %%
import pyabf
abf = pyabf.ABF("data/20n17033.abf")
print(abf)
# Out:
# ABF (version 2.5.0.0) with 1 channel (mV), sampled at 2.0 kHz, containing 1 sweep, having no tags, with a total length of 6.26 minutes, recorded with protocol "!2019_asenic_gapfree".

# %%
# abf.setSweep(0)
abf.setSweep(0)
plt.figure(figsize=(20, 10))
plt.plot(abf.sweepX, abf.sweepY)
plt.show()

# %%
abf.sweepX
# Out:
# array([  0.    ,   0.0005,   0.001 , ..., 375.6785, 375.679 , 375.6795])

# %%
abf.sweepY
# Out:
# array([-54.2511, -54.2847, -54.3213, ..., -53.3051, -53.2684, -53.2867],
#       dtype=float32)

# %%
sf.write('data/20n17033.wav', abf.sweepY, 2000, 'PCM_24')

# %%
ipd.Audio('data/20n17033.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df = pd.DataFrame(data = abf.sweepY, columns=['channel_1'])

# %%
df.to_csv('data/20n17033.csv')
